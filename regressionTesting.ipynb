# %%
import torch
import torchvision
import torchvision.transforms as transforms
from largerNetArchitecture import LargerNet
from networkAnalyzer import NetworkAnalyzer
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
import pandas as pd
from largerNetArchitecture import LargerNet
from torch.nn import MSELoss

# %%
# Read data
csv_data = pd.read_csv('data/simpleReg.csv')

a = csv_data['a'].values.reshape(-1, 1)
b = csv_data['b'].values.reshape(-1, 1)
y = csv_data['y'].values.reshape(-1, 1)

# Convert to Tensors
a_tensor = torch.tensor(a, dtype=torch.float32)
b_tensor = torch.tensor(b, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.float32)

# Combine input features
X_tensor = torch.cat((a_tensor, b_tensor), dim=1)

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X_tensor, y_tensor, test_size=0.2, random_state=42
)

# Create TensorDatasets
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)

# Define batch size
batch_size = 64

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
loss_fn = MSELoss()

analyzer = NetworkAnalyzer(model_architecture=LargerNet, amount_to_produce=5, success_loss=0.1, convergence_threshold=1, max_attempts=2)
analyzer.generate_networks(train_loader=train_loader, test_loader=test_loader, num_epochs=15, loss_fn=loss_fn)
# Out:
# Training Network 1
# Epoch 1/15
# Epoch [1], Loss: 0.0849
# Epoch 2/15
# Epoch [2], Loss: 0.1986
# Epoch 3/15
# Epoch [3], Loss: 0.1406
# Epoch 4/15
# Epoch [4], Loss: 0.3218
# Epoch 5/15
# Epoch [5], Loss: 0.2665
# Epoch 6/15
# Epoch [6], Loss: 0.0959
# Epoch 7/15
# Epoch [7], Loss: 0.0410
# Epoch 8/15
# Epoch [8], Loss: 0.1306
# Epoch 9/15
# Epoch [9], Loss: 0.0798
# Epoch 10/15
# Epoch [10], Loss: 0.0290
# Epoch 11/15
# Epoch [11], Loss: 0.1128
# Epoch 12/15
# Epoch [12], Loss: 0.0262
# Epoch 13/15
# Epoch [13], Loss: 0.0271
# Epoch 14/15
# Epoch [14], Loss: 0.0492
# Epoch 15/15
# Epoch [15], Loss: 0.0677
# [0.08493711054325104, 0.19862985610961914, 0.14058373868465424, 0.3218443691730499, 0.26653915643692017, 0.09594376385211945, 0.04101758822798729, 0.13056062161922455, 0.07984630018472672, 0.029020270332694054, 0.11279165744781494, 0.026241343468427658, 0.02710040658712387, 0.04918826371431351, 0.06772039085626602]
# loss_history[-1] = 0.06772039085626602
# loss_history[-2] = 0.04918826371431351
# Training Network 2
# Epoch 1/15
# Epoch [1], Loss: 0.1334
# Epoch 2/15
# Epoch [2], Loss: 0.3345
# Epoch 3/15
# Epoch [3], Loss: 0.4258
# Epoch 4/15
# Epoch [4], Loss: 0.0900
# Epoch 5/15
# Epoch [5], Loss: 0.2910
# Epoch 6/15
# Epoch [6], Loss: 0.2035
# Epoch 7/15
# Epoch [7], Loss: 0.1213
# Epoch 8/15
# Epoch [8], Loss: 0.0392
# Epoch 9/15
# Epoch [9], Loss: 0.0601
# Epoch 10/15
# Epoch [10], Loss: 0.0734
# Epoch 11/15
# Epoch [11], Loss: 0.0458
# Epoch 12/15
# Epoch [12], Loss: 0.1208
# Epoch 13/15
# Epoch [13], Loss: 0.0994
# Epoch 14/15
# Epoch [14], Loss: 0.0635
# Epoch 15/15
# Epoch [15], Loss: 0.1039
# [0.08493711054325104, 0.19862985610961914, 0.14058373868465424, 0.3218443691730499, 0.26653915643692017, 0.09594376385211945, 0.04101758822798729, 0.13056062161922455, 0.07984630018472672, 0.029020270332694054, 0.11279165744781494, 0.026241343468427658, 0.02710040658712387, 0.04918826371431351, 0.06772039085626602, 0.13339003920555115, 0.33452409505844116, 0.4257926940917969, 0.09001146256923676, 0.29098743200302124, 0.2035442441701889, 0.12126396596431732, 0.0391661673784256, 0.060138799250125885, 0.0734117403626442, 0.04576139152050018, 0.12076414376497269, 0.09938105195760727, 0.06348315626382828, 0.10389474034309387]
# loss_history[-1] = 0.10389474034309387
# loss_history[-2] = 0.06348315626382828
# Training Network 3
# Error: Maximum number of attempts reached without meeting success criteria.
# 1 successful networks created out of 5.
# Attemps:2, successfull networks: 1

# %%
from mpl_toolkits.mplot3d import Axes3D

# Create a grid of values
a_range = np.linspace(a_tensor.min(), a_tensor.max(), 50)
b_range = np.linspace(b_tensor.min(), b_tensor.max(), 50)
A, B = np.meshgrid(a_range, b_range)
grid = np.c_[A.ravel(), B.ravel()]
grid_tensor = torch.tensor(grid, dtype=torch.float32)

# Get predictions
network.eval()
with torch.no_grad():
    y_pred_grid = network(grid_tensor).numpy()

# Reshape predictions to match grid
Y_pred_grid = y_pred_grid.reshape(A.shape)

# Plot the surface
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(A, B, Y_pred_grid, cmap='viridis', alpha=0.8)

# Optionally plot the actual target function for comparison
# Compute actual Y values using the target function
Y_actual_grid = target_function(A, B)

# Plot the actual surface
ax.plot_wireframe(A, B, Y_actual_grid, color='r', label='Actual Function')

ax.set_xlabel('a')
ax.set_ylabel('b')
ax.set_zlabel('Predicted Y')
plt.title('3D Surface Plot of Predicted Y over a and b')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/cy/1ymz7q691kxczsvbmngmymg40000gn/T/ipykernel_65870/505923266.py in <module>
#       2
#       3 # Create a grid of values
# ----> 4 a_range = np.linspace(a_tensor.min(), a_tensor.max(), 50)
#       5 b_range = np.linspace(b_tensor.min(), b_tensor.max(), 50)
#       6 A, B = np.meshgrid(a_range, b_range)
#
# NameError: name 'np' is not defined
